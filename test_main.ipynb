# %%
import polars as pl
from lib import stats_mean, stats_median, stats_std

# %%
# %run main.ipynb
# Out:
# mean:77.44
#
# median:77.0
#
# std_dev:12.732987850140937

# %%
def test_values(df):
    assert (stats_mean(df)) == 77.44
    assert (stats_median(df)) == 77.0
    assert (stats_std(df)) == 12.732987850140937
    print("CI passed")

# %%
df = pl.read_csv("class_grades.csv")
test_values(df)
# Out:
# CI passed
